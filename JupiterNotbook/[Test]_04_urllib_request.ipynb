# %% [markdown]
# ## urllib.request
# 역할 : 인터넷 자원 다운로드
# 주의 : requests와 다름
# 사용 : request.urlretrieve("인터넷 자원 주소", "이름 설정")

# %% [markdown]
# #### 예제 : 바탕화면에 이미지 저장
# ![세종대 사진](data:image/png;base64,...
# )

# %%
from urllib import request    

# 사용자 이름 (바탕화면)
UserName = "pwb11"
Folder=f"C:/Users/{UserName}/Desktop/"

# 이미지 링크 (세종대학교 호텔경영학과)
imgLink = "data:image/png;base64,..."

# 파일명 설정
imgName = "TestImg"

# 이미지 경로(이름) 
savename = Folder+imgName+".jpg"

# 이미지 파일로 저장
request.urlretrieve(imgLink, savename)

print("이미지 파일이 저장되었습니다...!")
# Out:
# 이미지 파일이 저장되었습니다...!

# %% [markdown]
# #### 참고사항
# - [urllib.request API](https://docs.python.org/ko/3/library/urllib.request.html#module-urllib.request)
# - [이미지 동영상 다운로드](https://blog.naver.com/kiddwannabe/221358581642)

# %%
import os
import urllib.request

# 이미지가 있는 url 주소 작성
url = "data:image/png;base64,..."

# 다운로드를 위해 파일 경로와 파일 이름 작성
UserName = "pwb11"                                # 본인 컴퓨터 사용자 계정
forderName = "0_sejong"                           # 폴더명
forderPath = f"c:/Users/{UserName}/{forderName}/" # 주피터 노트북 디폴트 경로 + 폴더명
outfile = "Sejong_University.png"                 # 본인이 원하는 파일명
# full_path = forderPath + outfile

# 폴더가 없으면 생성 후 이미지 저장, 있으면 이미지 저장
if not os.path.isdir(forderPath) :
    os.makedirs(forderPath)

# 이미지 경로에 다운로드
urllib.request.urlretrieve(url, forderPath+outfile)

# 성공 메시지
print("complete!")

# %% [markdown]
# **url 찾는 법 :**
# google 접속 -> 세종대학교로 검색 -> 이미지 탭 -> 이미지 마우스 오른쪽 버튼 -> 이미지 주소 복사
