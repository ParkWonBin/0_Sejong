# %%
#호텔 어드바이저 댓글 크롤링

# %%
# === [Part 1 : 라이블러리 참조 및 브라우저 열기] ======
from selenium import webdriver # 봇으로 페이지 들어가기
from bs4 import BeautifulSoup  # 페이지 특정 부분 추출하기

# 크롬 브라우저 열기
driver = webdriver.Chrome('C:/chromedriver.exe')

# 롯데호텔 룸 프로모션 화면으로 이동
url = "https://www.tripadvisor.co.kr/Hotel_Review-g294197-d306130-Reviews-Lotte_Hotel_Seoul-Seoul.html"
driver.get(url)

# %%
# === [Part 2 : 데이터 추출 및 출력] ======

# BeautifulSoup로 소스 받아오기
html = driver.page_source
soup = BeautifulSoup(html, "lxml")

# 데이터 선택해서 리스트로 저장
ReviewID    = soup.select('.social-member-event-MemberEventOnObjectBlock__event_type--3njyv span a')
ReviewTitle = soup.select('.location-review-review-list-parts-ReviewTitle__reviewTitleText--2tFRT')
ReviewText  = soup.select('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC')
ReviewDate  = soup.select('.location-review-review-list-parts-EventDate__event_date--1epHa')

# 저장한 데이터 출력 함수 정의
def PrintData() :
    for i in range(len(ReviewID)):
        print(" #",i+1,':', ReviewDate[i].text.lstrip('숙박 날짜 :')) 
        print('이름 :', ReviewID[i].text) 
        print('제목 :', ReviewTitle[i].text)
        print('내용 :', ReviewText[i].text)
        print('\n')

#출력
PrintData()
# Out:
#  # 1 : 2020년 1월
# 이름 : 루키즌스
# 제목 : 설연휴 마지막날 휴식
# 내용 : 설연휴의 마지막날을 와이프와 함께 휴식차 방문 하였습니다. 독감 바이러스때문에 걱정되어 아기는 데리고 오지 못했는데 체크인데스크에 바이러스 대비 열화상카메라,소독제를 설치해두었더라구요.  특급호텔이라 외국인들 방문도 많아 저희 부부만 방문하는것도 걱정됐는데 그런부분을보니 조금이나마 안심이되었습니다^^  다소 늦은 체크인에도 직원분이 전망좋은 객실 배정해주셔 이번 호캉스를 잘 보낼 수 있었습니다.
#
#
#  # 2 : 2020년 1월
# 이름 : syul
# 제목 : 설 연휴의 꿈같은 휴식
# 내용 : 그동안 너무 쉬지못해 설 연휴에 나와 아내를 위한 휴식을 선택했는데 정말 좋은 호텔을 선택하게 되어 편한히 쉴수 있었습니다 호텔에 도착하면 첫인상이 중요한데 저희를 안내해주신 Daisy 라는 직원분이  너무 친절하게 안내해 주셔서 기분좋게 시작할수 있없습니다 전체적으로 호텔 시설이 너부 체계적으로 잘 되어있어서 어떤 시설을 이용해도 부족합이 없없던거 같습니다 특히 수영장은 겨울에 움추린 제몸의 긴장을 풀기에 너무 좋앗습니다 객시에서의 취침은 정말 오랜만에 깊은 잠을 청할수 있도록 푹 안기는듯했고  개운한 아침을 맞아 찾은 조식은 아침을 잘 안먹는 저에겐 좋은 약을 먹는것처럼 행복했습니다 다음에 다시 쉼이 필요할땐 항상 이곳을 찾도록 하겠습니다 이번 여행에 도움을주신 ,Daisy님께 다시한번 감사 말씀드립니다
#
#
#  # 3 : 2020년 1월
# 이름 : 이주현
# 제목 : 친절과 디테일로 완성시켜준 호캉스
# 내용 : 구정 연휴 말미, 아이를 데리고 가족단위로 투숙하였습니다. 아직 아이가 너무 어리기에 온돌 방으로 요청드렸으며 어쩌다 보니, 체크인 시간보다 조금 이른 시간에 도착하였습니다. 칭얼거리는 아이가 신경쓰이던 찰나, 프런트 직원분께서 싹싹하게 아이도 챙겨주셨고, 혹 온돌 방이면 아기용 요, 이불 등 추가로 필요한 것이 있는지 먼저 물어봐 주신 덕에, 저희가 미처 생각지 못한 부분까지 잘 챙길 수 있었습니다. 덕분에 연휴의 마지막을 행복하게 잘 보냈습니다.
#
#
#  # 4 : 2020년 1월
# 이름 : kangta choi
# 제목 : 설연휴 기분좋은 휴가
# 내용 : 설연휴 가족과 함께한 롯데호텔 클럽룸 연휴라그런지클럽라운지에 매우많은 손님들이 있었지만 직원분들의 친절과 배려로 기분좋게 이용할 수 있었습니다 도심속에서의 수영장 또한 즐거운 경험 이었습니다
#
#
#  # 5 : 2019년 12월
# 이름 : Cocojang
# 제목 : 롯데호텔 최고!!!
# 내용 : 재작년에 이어 2019년 연말에도 가족과 함께 롯데호텔 다녀왔습니다 직원분들도 모두 친절하고 룸컨디션도 클럽라운지도 모두 대만족~~울 가족 모두 힐링하고 왔습니다~~ 올 연말에도 롯데호텔에서 보낼거에요~♡

# %%
# === [Part 3 : 데이터 추가 로드 및 출력 ] ======

# 다음 페이지  버튼 클릭
driver.find_element_by_css_selector('.ui_pagination.is-centered:nth-child(1)').click() #다음 버튼 찾아서 클릭
# (*)위에 코드가 계속 문제 일어나는 부분, 아직도 수정 중
    
# 로드된 페이지 읽기 
html = driver.page_source
soup = BeautifulSoup(html, "lxml")

#데이터 추가하기
ReviewID    += soup.select('.social-member-event-MemberEventOnObjectBlock__event_type--3njyv span a')
ReviewTitle += soup.select('.location-review-review-list-parts-ReviewTitle__reviewTitleText--2tFRT')
ReviewText  += soup.select('.location-review-review-list-parts-ExpandableReview__reviewText--gOmRC')
ReviewDate  += soup.select('.location-review-review-list-parts-EventDate__event_date--1epHa')

#출력
PrintData()
# Out:
#  # 1 : 2020년 1월
# 이름 : 루키즌스
# 제목 : 설연휴 마지막날 휴식
# 내용 : 설연휴의 마지막날을 와이프와 함께 휴식차 방문 하였습니다. 독감 바이러스때문에 걱정되어 아기는 데리고 오지 못했는데 체크인데스크에 바이러스 대비 열화상카메라,소독제를 설치해두었더라구요.  특급호텔이라 외국인들 방문도 많아 저희 부부만 방문하는것도 걱정됐는데 그런부분을보니 조금이나마 안심이되었습니다^^  다소 늦은 체크인에도 직원분이 전망좋은 객실 배정해주셔 이번 호캉스를 잘 보낼 수 있었습니다.
#
#
#  # 2 : 2020년 1월
# 이름 : syul
# 제목 : 설 연휴의 꿈같은 휴식
# 내용 : 그동안 너무 쉬지못해 설 연휴에 나와 아내를 위한 휴식을 선택했는데 정말 좋은 호텔을 선택하게 되어 편한히 쉴수 있었습니다 호텔에 도착하면 첫인상이 중요한데 저희를 안내해주신 Daisy 라는 직원분이  너무 친절하게 안내해 주셔서 기분좋게 시작할수 있없습니다 전체적으로 호텔 시설이 너부 체계적으로 잘 되어있어서 어떤 시설을 이용해도 부족합이 없없던거 같습니다 특히 수영장은 겨울에 움추린 제몸의 긴장을 풀기에 너무 좋앗습니다 객시에서의 취침은 정말 오랜만에 깊은 잠을 청할수 있도록 푹 안기는듯했고  개운한 아침을 맞아 찾은 조식은 아침을 잘 안먹는 저에겐 좋은 약을 먹는것처럼 행복했습니다 다음에 다시 쉼이 필요할땐 항상 이곳을 찾도록 하겠습니다 이번 여행에 도움을주신 ,Daisy님께 다시한번 감사 말씀드립니다
#
#
#  # 3 : 2020년 1월
# 이름 : 이주현
# 제목 : 친절과 디테일로 완성시켜준 호캉스
# 내용 : 구정 연휴 말미, 아이를 데리고 가족단위로 투숙하였습니다. 아직 아이가 너무 어리기에 온돌 방으로 요청드렸으며 어쩌다 보니, 체크인 시간보다 조금 이른 시간에 도착하였습니다. 칭얼거리는 아이가 신경쓰이던 찰나, 프런트 직원분께서 싹싹하게 아이도 챙겨주셨고, 혹 온돌 방이면 아기용 요, 이불 등 추가로 필요한 것이 있는지 먼저 물어봐 주신 덕에, 저희가 미처 생각지 못한 부분까지 잘 챙길 수 있었습니다. 덕분에 연휴의 마지막을 행복하게 잘 보냈습니다.
#
#
#  # 4 : 2020년 1월
# 이름 : kangta choi
# 제목 : 설연휴 기분좋은 휴가
# 내용 : 설연휴 가족과 함께한 롯데호텔 클럽룸 연휴라그런지클럽라운지에 매우많은 손님들이 있었지만 직원분들의 친절과 배려로 기분좋게 이용할 수 있었습니다 도심속에서의 수영장 또한 즐거운 경험 이었습니다
#
#
#  # 5 : 2019년 12월
# 이름 : Cocojang
# 제목 : 롯데호텔 최고!!!
# 내용 : 재작년에 이어 2019년 연말에도 가족과 함께 롯데호텔 다녀왔습니다 직원분들도 모두 친절하고 룸컨디션도 클럽라운지도 모두 대만족~~울 가족 모두 힐링하고 왔습니다~~ 올 연말에도 롯데호텔에서 보낼거에요~♡
#
#
#  # 6 : 2020년 1월
# 이름 : 루키즌스
# 제목 : 설연휴 마지막날 휴식
# 내용 : 설연휴의 마지막날을 와이프와 함께 휴식차 방문 하였습니다. 독감 바이러스때문에 걱정되어 아기는 데리고 오지 못했는데 체크인데스크에 바이러스 대비 열화상카메라,소독제를 설치해두었더라구요.  특급호텔이라 외국인들 방문도 많아 저희 부부만 방문하는것도 걱정됐는데 그런부분을보니 조금이나마 안심이되었습니다^^  다소 늦은 체크인에도 직원분이 전망좋은 객실 배정해주셔 이번 호캉스를 잘 보낼 수 있었습니다.
#
#
#  # 7 : 2020년 1월
# 이름 : syul
# 제목 : 설 연휴의 꿈같은 휴식
# 내용 : 그동안 너무 쉬지못해 설 연휴에 나와 아내를 위한 휴식을 선택했는데 정말 좋은 호텔을 선택하게 되어 편한히 쉴수 있었습니다 호텔에 도착하면 첫인상이 중요한데 저희를 안내해주신 Daisy 라는 직원분이  너무 친절하게 안내해 주셔서 기분좋게 시작할수 있없습니다 전체적으로 호텔 시설이 너부 체계적으로 잘 되어있어서 어떤 시설을 이용해도 부족합이 없없던거 같습니다 특히 수영장은 겨울에 움추린 제몸의 긴장을 풀기에 너무 좋앗습니다 객시에서의 취침은 정말 오랜만에 깊은 잠을 청할수 있도록 푹 안기는듯했고  개운한 아침을 맞아 찾은 조식은 아침을 잘 안먹는 저에겐 좋은 약을 먹는것처럼 행복했습니다 다음에 다시 쉼이 필요할땐 항상 이곳을 찾도록 하겠습니다 이번 여행에 도움을주신 ,Daisy님께 다시한번 감사 말씀드립니다
#
#
#  # 8 : 2020년 1월
# 이름 : 이주현
# 제목 : 친절과 디테일로 완성시켜준 호캉스
# 내용 : 구정 연휴 말미, 아이를 데리고 가족단위로 투숙하였습니다. 아직 아이가 너무 어리기에 온돌 방으로 요청드렸으며 어쩌다 보니, 체크인 시간보다 조금 이른 시간에 도착하였습니다. 칭얼거리는 아이가 신경쓰이던 찰나, 프런트 직원분께서 싹싹하게 아이도 챙겨주셨고, 혹 온돌 방이면 아기용 요, 이불 등 추가로 필요한 것이 있는지 먼저 물어봐 주신 덕에, 저희가 미처 생각지 못한 부분까지 잘 챙길 수 있었습니다. 덕분에 연휴의 마지막을 행복하게 잘 보냈습니다.
#
#
#  # 9 : 2020년 1월
# 이름 : kangta choi
# 제목 : 설연휴 기분좋은 휴가
# 내용 : 설연휴 가족과 함께한 롯데호텔 클럽룸 연휴라그런지클럽라운지에 매우많은 손님들이 있었지만 직원분들의 친절과 배려로 기분좋게 이용할 수 있었습니다 도심속에서의 수영장 또한 즐거운 경험 이었습니다
#
#
#  # 10 : 2019년 12월
# 이름 : Cocojang
# 제목 : 롯데호텔 최고!!!
# 내용 : 재작년에 이어 2019년 연말에도 가족과 함께 롯데호텔 다녀왔습니다 직원분들도 모두 친절하고 룸컨디션도 클럽라운지도 모두 대만족~~울 가족 모두 힐링하고 왔습니다~~ 올 연말에도 롯데호텔에서 보낼거에요~♡
#
#
#  # 11 : 2019년 12월
# 이름 : CSM
# 제목 : 너무 좋아요~
# 내용 : 객실이용좋고 수영장.휘트니스시설도 무료이용할수있어 좋았고 직원들도 너무 친절해서 좋았어욤~~^.^ 애들데리고 가기 좋네요^.^
#
#
#  # 12 : 2019년 12월
# 이름 : Jenn
# 제목 : 좋은 곳에서 즐거운 시간 보냈습니다~!!
# 내용 : 요즘 바쁜 시간 속에서 항상 피곤하고 지친 상태였는데 친구들과 연말&크리스마스 기념으로 서울 도심에서 호캉스를 즐기기 위해 롯데호텔 서울을 선택했습니다!! 서울 한 가운데 위치하여 있어 접근성은 물론이고 바로 밑에 백화점, 영플라자 등 편의 시설도 많습니다. 그리고 백화점과 이어져 있어 찾아가기도 쉬워요!! 무엇보다 객실에 딱 들어갔을 때 깔끔하고 분위기가 너무 좋았습니다ㅎㅎ 특히 화장실이 정말 청결했어요!! 또 필요한 것이 있어 직원분께 부탁했더니 바로 가져다주시고 친절했습니다!! 또 다음날 조식은 클럽 라운지 조식을 이용했는데 사람이 많지 않고 메뉴가 알차서 맛있게 먹었습니다ㅎㅎ 요즘 좋은 사람들과 좋은 곳에서 즐거운 시간 보내기 쉽지 않은데그럴 때 롯데호텔 서울에서의 호캉스 정말 추천합니다!!
#
#
#  # 13 : 2019년 12월
# 이름 : yoonju cho
# 제목 : 결혼 25주년 기념으로 큰맘 먹고  성탄절 이브 롯데 호텔에 숙박을 하게 되었습니다
# 내용 : 호텔에 들어 서자 마자 성탄절이구나   요즘 찾아 보기 힘든 분위기 였는대 역쉬나 화려하고 캐럴송이 저절로 나오는 분위기에 객실이 너무 아늑하고 깨끗해서  30주년 35주년 꼭 다시 찾을것 같은  호텔입니다  호텔 체크인에서 부터 무엇 하나 흠잡을 것이 없는 성탄절 이였습니다
#
#
#  # 14 : 2019년 12월
# 이름 : 꼬라지
# 제목 : 즐거운 여행 재방문 100% 입니다.~
# 내용 : 연말을 맞이 하여 3대가  찾은 롯데 호텔은 저한테 감동을 선사했네요~  어린아이 부터 연세가 많으시  부모님까 모두 만족한 여행이였습니다. 연말이라서 많이  사람들로  불편을 예상했지만 제 예상을 깨고 직원분들의 친절 함에 즐거운 여행였습니다. 특히 어린아이 와  연세많은 신 부모님과 수영장 및 휘트니스 이용시 걱정을 많이했는데 직원분들이 먼저 다가오셔셔 이용방법도 설명해주시고 미소를 잃지 않는 서비스 정말 잊지 못할것 같네요~~ 룸 컨티션 ,직원분들 서비스 마인드 , 훌륭한 위치( 관광지.쇼핑센터), 보너스로 맛있는 조식까지 재 방문 100%입니다.~ 즐거운 여행 만들어 주셔서 감사합니다.^^
#
#
#  # 15 : 2019년 8월
# 이름 : 정인우
# 제목 : 추천합니다
# 내용 : 두말 필요없이 깔끔한 시설과 서비스로 만족합니다 조식도 맛있었고 근처에 관광지가 가까워 친구들과 즐겁게 여행할수 있었습니다
#
#
#  # 16 : 2019년 12월
# 이름 : CSM
# 제목 : 너무 좋아요~
# 내용 : 객실이용좋고 수영장.휘트니스시설도 무료이용할수있어 좋았고 직원들도 너무 친절해서 좋았어욤~~^.^ 애들데리고 가기 좋네요^.^
#
#
#  # 17 : 2019년 12월
# 이름 : Jenn
# 제목 : 좋은 곳에서 즐거운 시간 보냈습니다~!!
# 내용 : 요즘 바쁜 시간 속에서 항상 피곤하고 지친 상태였는데 친구들과 연말&크리스마스 기념으로 서울 도심에서 호캉스를 즐기기 위해 롯데호텔 서울을 선택했습니다!! 서울 한 가운데 위치하여 있어 접근성은 물론이고 바로 밑에 백화점, 영플라자 등 편의 시설도 많습니다. 그리고 백화점과 이어져 있어 찾아가기도 쉬워요!! 무엇보다 객실에 딱 들어갔을 때 깔끔하고 분위기가 너무 좋았습니다ㅎㅎ 특히 화장실이 정말 청결했어요!! 또 필요한 것이 있어 직원분께 부탁했더니 바로 가져다주시고 친절했습니다!! 또 다음날 조식은 클럽 라운지 조식을 이용했는데 사람이 많지 않고 메뉴가 알차서 맛있게 먹었습니다ㅎㅎ 요즘 좋은 사람들과 좋은 곳에서 즐거운 시간 보내기 쉽지 않은데그럴 때 롯데호텔 서울에서의 호캉스 정말 추천합니다!!
#
#
#  # 18 : 2019년 12월
# 이름 : yoonju cho
# 제목 : 결혼 25주년 기념으로 큰맘 먹고  성탄절 이브 롯데 호텔에 숙박을 하게 되었습니다
# 내용 : 호텔에 들어 서자 마자 성탄절이구나   요즘 찾아 보기 힘든 분위기 였는대 역쉬나 화려하고 캐럴송이 저절로 나오는 분위기에 객실이 너무 아늑하고 깨끗해서  30주년 35주년 꼭 다시 찾을것 같은  호텔입니다  호텔 체크인에서 부터 무엇 하나 흠잡을 것이 없는 성탄절 이였습니다
#
#
#  # 19 : 2019년 12월
# 이름 : 꼬라지
# 제목 : 즐거운 여행 재방문 100% 입니다.~
# 내용 : 연말을 맞이 하여 3대가  찾은 롯데 호텔은 저한테 감동을 선사했네요~  어린아이 부터 연세가 많으시  부모님까 모두 만족한 여행이였습니다. 연말이라서 많이  사람들로  불편을 예상했지만 제 예상을 깨고 직원분들의 친절 함에 즐거운 여행였습니다. 특히 어린아이 와  연세많은 신 부모님과 수영장 및 휘트니스 이용시 걱정을 많이했는데 직원분들이 먼저 다가오셔셔 이용방법도 설명해주시고 미소를 잃지 않는 서비스 정말 잊지 못할것 같네요~~ 룸 컨티션 ,직원분들 서비스 마인드 , 훌륭한 위치( 관광지.쇼핑센터), 보너스로 맛있는 조식까지 재 방문 100%입니다.~ 즐거운 여행 만들어 주셔서 감사합니다.^^
#
#
#  # 20 : 2019년 8월
# 이름 : 정인우
# 제목 : 추천합니다
# 내용 : 두말 필요없이 깔끔한 시설과 서비스로 만족합니다 조식도 맛있었고 근처에 관광지가 가까워 친구들과 즐겁게 여행할수 있었습니다

# %%
# === [Part 4 : 오류노트 ] ======
# (*) 다음페이지 문제

# 1. 주소로 링크 에러
# 1.1. 증상 : 새로고침 되면서 1페이지로 돌아감
# 1.2. 코드 : 
    # pageNum = 5
    # url = 'https://www.tripadvisor.co.kr/Hotel_Review-g294197-d306130-Reviews-or'+str((pageNum)*5)+'-Lotte_Hotel_Seoul-Seoul.html#REVIEWS'
    # driver.get(url)
# 1.3. 해결 : 다음 버튼 눌러서 로드하기로 함.
# 1.4. 이유 : 해당 페이지에서 '주소 직접 입력'은 막아놓은 듯, 다음 버튼 눌러서 들어가야 세션 유지됨.

# 2. 다음 페이지 버튼 에러
# 2.1. 증상 : 다음 페이지 3번 이상 반복 시 에러남.(15번 게시글까지만 정상적으로 작동함)
# 2.2. 코드 : driver.find_element_by_css_selector('.ui_button.nav.next.primary').click() 
# 2.3. 해결 : 상위 테그의 nth-child(1)로 선택하니 해결됨
# 2.4  이유 : 모르겠음

# 3. 댓글 4페이지 이상 못넘어가는 문제. 
# 3.1. 증상 : 4페이지(15번 게시글)에서 더이상 넘어가지 못하고 같은 내용을 반복해서 로드함
# 3.2. 코드 : driver.find_element_by_css_selector('.ui_pagination.is-centered:nth-child(1)').click()
# Out:
#  # 1 : 2019년 12월
# 이름 : elly
# 제목 : 좋네요~~
# 내용 : 오랜만의 친구들과의 모임있었는데 좋은곳에서 최상의 서비스에  깔끔하고 맛있는조식까지 최고였어요 친구들과의 추억 만들기 장소로 딱입니다 또 기회가 된다면 오고싶네요
#
#
#  # 2 : 2019년 12월
# 이름 : Just min
# 제목 : 최고의 호텔❤❤
# 내용 : 친구들과 우정여행으로 찾게된 롯데호텔 시설. 서비스. 친절함 어느것 하나 빠지지 않는 인상깊은 곳이었어요. 서울 여행을 할 친구들에게 강추하고 싶은곳이네요. 즐겁고 행복한 여행이되게 해주셔서 감사합니다.
#
#
#  # 3 : 2019년 11월
# 이름 : Amwvs
# 제목 : 친구들과의 여행
# 내용 : 룸도 깨끗하고 훌륭하며 조식도 종류도 많고 맛있습니다 종로 명동으로 가기도 좋고 지하철이 연결되어 위치도 아주 좋아요
#
#
#  # 4 : 2019년 11월
# 이름 : kssline
# 제목 : 서울 야경과 럭셔리호텔서비스 최상으로 즐기기
# 내용 : 모처럼 짬을 내어 휴가를 내어 아내의 함께 호텔롯데 서울에서 1박을 묵었다. 청계천 야경을 즐기고 남산이 훤히 보이는 서울롯데는 최고의 도심 특급호텔이다. 황금빛 로비와 화려한 주변 조명으로 분위기 업, 최상의 시설과 직원들의 객실서비스로 기쁨이 배가되는 최고의 호텔이다. 깨끗하고 아늑한 룸과 라센느에서의 아침 조식 서비스, 친절했던 직원들의 미소로 롯데호텔은 군더더기 하나 없는 휴가와 여행의 추억이 되세겨지는 아름다운 곳이다.
#
#
#  # 5 : 2019년 9월
# 이름 : 영아 김
# 제목 : 결혼기념일
# 내용 : 르루즈 패키지로 예약했어요.  수영장 이용했는데 깨끗하고 쾌적하고 안전요원도 있었어요.  아가들이 많아서 성인이 수영하기엔 적당하지 않았지만, 수영회원이 없는 경우에 한해 회원전용레인을 쓸수있게 해줘서 좋았어요. 라세느 저녁 먹었는데 굉장히 만족했습니다.  아침에 조식을 갔는데 한식류가 다양하지 않은 점이 아쉬웠어요.  외국 조식뷔페랑 비슷하더라구요.  그냥 밑반찬 정도? 그리고 르루즈애프터눈티 예약시간이 늦어 레이트체크아웃 부탁드렸는데 흔쾌히 들어주셔서 감사했습니다!
#
#
#  # 6 : 2020년 1월
# 이름 : 까망콩
# 제목 : 롯데호텔서울
# 내용 : 깔끔하고 럭셔리한... 직원들서비스도 좋고요.. 30층라 전망도 좋았어요.. 라세는음식과 서비스도 좋고요..시간이 부족해서 너무너무 아쉬웠어요..
#
#
#  # 7 : 2020년 1월
# 이름 : js6025
# 제목 : 롯데호텔ㅡ소공점ㅡ최고직원 주남영님 ! 고마워요
# 내용 : 롯데호텔 소공점ㅡExecutive Tower  스위트룸 프레지덴셜3050 2020.0103~01.05 헤르메프 신년회 2박3일동안 하나의 불편함없이  모임도 잘 마치고 집에 돌아왔다. 시계를 놓고온것도 모르고있다가 친절한 주남영씨 안내메세지로    시계를 찾을수가 있었다. 입실해있는동안  필요한게 있는지 불편한게 있는지 , 호텔 이용법도 친절하게 알려주셨는데  마지막까지 도움을 준 주남영님! 너무고맙고 롯데호텔 ㅡ소공점 의  최고  친절 직원입니다. 다시 한 번 고마워요^^  다음 모임할때도 주남영님께 부탁드리도록 하겠습니다. 감사하고 더 좋은 일들로 가득하실껍니다^^
#
#
#  # 8 : 2019년 12월
# 이름 : Sightsee23983459202
# 제목 : 다음에도 또방문할겁니다.
# 내용 : 추석연휴에이어 2019년 마지막날 가족과 또 방문을하였습니다 역시 롯데서울에 감격하여 이번구정연휴에도 또 방문예정입니다 특히 추석에도 이번에도 인지서비스를 잘해주신 김현수메니저 덕분에 편안휴식과 즐거운시간을 보냈습니다 메니저님감사합니다. 쇼핑과 주변볼거리가 최고인 롯데호텔 서울을 추천합니다
#
#
#  # 9 : 2019년 12월
# 이름 : kdj826
# 제목 : 너무 행복했던 가족여행
# 내용 : 12월8일 부모님결혼기념일을 기념해서 가족들과 함께 롯데호텔서울에1박2일을 보냈습니다.보내는동안 방이 무척깨끗하고 넓어서 좋았고 직원분들도 매우 친절해서 만족스러운 가족여행ㅇㅣ 되었습니다 다음에도 또이용하고 싶습니다.
#
#
#  # 10 : 2019년 12월
# 이름 : Choi
# 제목 : 롯데호텔 서울 너무너무 좋아요!!!!!!!❤️❤️❤️❤️
# 내용 : 친구들과 연말 파티를 하였습니다. 깔끔하고 넓은 객실과 넉넉한 침대 그리고 미리 사람 수 대로 어메너티가 채워넣어진 욕실은 넓고 깨끗하였습니다. 위생적이고 맛있는 라세느 뷔페와 조식 뷔페가 인상적이었고 여태 머문 호텔 중 청결도와 친절함, 뷔페의 맛과 위생이 가장 마음에 드는 호텔이었습니다^^ 머무는 동안 정말 행복했습니다^^ 돈 많이 벌어 다시 올게요.
#
#
#  # 11 : 2019년 12월
# 이름 : youth
# 제목 : 롯데호텔 역시 최고네요
# 내용 : 친구 부부와 함께 투숙하였는데 룸 컨디션도 너무 좋았으며, 피트니스 시설도 매우 좋았습니다. 수영장은 아기와 함께 놀기 좋았으며 체련장은 깨끗하게 관리되고 있는 것 같았습니다. 직원들 인사성도 너무 좋았으며, 말 한마디 한마디가 신경써주는 것 같아 대접받고 가는 느낌이였습니다.
#
#
#  # 12 : 2019년 12월
# 이름 : Hanze Ryu
# 제목 : 롯데호텔 수영장,헬스장
# 내용 : 롯데호텔 수영장과 핼스장 이용해 보았는데요 관리가 잘되어있어서 깔끔하고 좋더군요 직원들도 친절해서 가족과 아이들 데려가기에도 좋은것 같습니다
#
#
#  # 13 : 2019년 12월
# 이름 : Ingo
# 제목 : 수영장 최고
# 내용 : 백화점도 가깝고 수영장 시설 대박입니다. 특히나 직원분들이 다들 이쁘고 친절하네용.. 다음에 호텔 가게되면 여기 이용할듯
#
#
#  # 14 : 2019년 12월
# 이름 : 김포타
# 제목 : 가족과 함께
# 내용 : 부모님 모시고 롯데호텔에 처음으로 투숙했는데 너무 만족 스러웠습니다 직원들도 친절하고 아이는 수영장에서 놀고 어머님은 사우나 이용하시고 좋아하시는 모습을 보니 효도 한거같아 뿌듯합니다
#
#
#  # 15 : 2019년 12월
# 이름 : 이정만
# 제목 : 롯데호텔  서울 라세느.
# 내용 : 1년동안 수고한 우리 가족을 위해 모처럼 여유있게 년말을 누리고 싶어서 라세느부페식당을 방문했습니다. 힘들게 예약한 만큼 기대도 컸는데 음식도 너무 맛있고 직원들도 너무 친절해서 정말 즐건 시간을 보냈습니다. 로비에서도 공연도 있었고 뜻깊은 시간을 보냈습니다. 다음에는 친구들과 모임을 여기서 가져야겠어여.
#
#
#  # 16 : 2019년 12월
# 이름 : CSM
# 제목 : 너무 좋아요~
# 내용 : 객실이용좋고 수영장.휘트니스시설도 무료이용할수있어 좋았고 직원들도 너무 친절해서 좋았어욤~~^.^ 애들데리고 가기 좋네요^.^
#
#
#  # 17 : 2019년 12월
# 이름 : Jenn
# 제목 : 좋은 곳에서 즐거운 시간 보냈습니다~!!
# 내용 : 요즘 바쁜 시간 속에서 항상 피곤하고 지친 상태였는데 친구들과 연말&크리스마스 기념으로 서울 도심에서 호캉스를 즐기기 위해 롯데호텔 서울을 선택했습니다!! 서울 한 가운데 위치하여 있어 접근성은 물론이고 바로 밑에 백화점, 영플라자 등 편의 시설도 많습니다. 그리고 백화점과 이어져 있어 찾아가기도 쉬워요!! 무엇보다 객실에 딱 들어갔을 때 깔끔하고 분위기가 너무 좋았습니다ㅎㅎ 특히 화장실이 정말 청결했어요!! 또 필요한 것이 있어 직원분께 부탁했더니 바로 가져다주시고 친절했습니다!! 또 다음날 조식은 클럽 라운지 조식을 이용했는데 사람이 많지 않고 메뉴가 알차서 맛있게 먹었습니다ㅎㅎ 요즘 좋은 사람들과 좋은 곳에서 즐거운 시간 보내기 쉽지 않은데그럴 때 롯데호텔 서울에서의 호캉스 정말 추천합니다!!
#
#
#  # 18 : 2019년 12월
# 이름 : yoonju cho
# 제목 : 결혼 25주년 기념으로 큰맘 먹고  성탄절 이브 롯데 호텔에 숙박을 하게 되었습니다
# 내용 : 호텔에 들어 서자 마자 성탄절이구나   요즘 찾아 보기 힘든 분위기 였는대 역쉬나 화려하고 캐럴송이 저절로 나오는 분위기에 객실이 너무 아늑하고 깨끗해서  30주년 35주년 꼭 다시 찾을것 같은  호텔입니다  호텔 체크인에서 부터 무엇 하나 흠잡을 것이 없는 성탄절 이였습니다
#
#
#  # 19 : 2019년 12월
# 이름 : 꼬라지
# 제목 : 즐거운 여행 재방문 100% 입니다.~
# 내용 : 연말을 맞이 하여 3대가  찾은 롯데 호텔은 저한테 감동을 선사했네요~  어린아이 부터 연세가 많으시  부모님까 모두 만족한 여행이였습니다. 연말이라서 많이  사람들로  불편을 예상했지만 제 예상을 깨고 직원분들의 친절 함에 즐거운 여행였습니다. 특히 어린아이 와  연세많은 신 부모님과 수영장 및 휘트니스 이용시 걱정을 많이했는데 직원분들이 먼저 다가오셔셔 이용방법도 설명해주시고 미소를 잃지 않는 서비스 정말 잊지 못할것 같네요~~ 룸 컨티션 ,직원분들 서비스 마인드 , 훌륭한 위치( 관광지.쇼핑센터), 보너스로 맛있는 조식까지 재 방문 100%입니다.~ 즐거운 여행 만들어 주셔서 감사합니다.^^
#
#
#  # 20 : 2019년 8월
# 이름 : 정인우
# 제목 : 추천합니다
# 내용 : 두말 필요없이 깔끔한 시설과 서비스로 만족합니다 조식도 맛있었고 근처에 관광지가 가까워 친구들과 즐겁게 여행할수 있었습니다
#
#
#  # 21 : 2019년 12월
# 이름 : CSM
# 제목 : 너무 좋아요~
# 내용 : 객실이용좋고 수영장.휘트니스시설도 무료이용할수있어 좋았고 직원들도 너무 친절해서 좋았어욤~~^.^ 애들데리고 가기 좋네요^.^
#
#
#  # 22 : 2019년 12월
# 이름 : Jenn
# 제목 : 좋은 곳에서 즐거운 시간 보냈습니다~!!
# 내용 : 요즘 바쁜 시간 속에서 항상 피곤하고 지친 상태였는데 친구들과 연말&크리스마스 기념으로 서울 도심에서 호캉스를 즐기기 위해 롯데호텔 서울을 선택했습니다!! 서울 한 가운데 위치하여 있어 접근성은 물론이고 바로 밑에 백화점, 영플라자 등 편의 시설도 많습니다. 그리고 백화점과 이어져 있어 찾아가기도 쉬워요!! 무엇보다 객실에 딱 들어갔을 때 깔끔하고 분위기가 너무 좋았습니다ㅎㅎ 특히 화장실이 정말 청결했어요!! 또 필요한 것이 있어 직원분께 부탁했더니 바로 가져다주시고 친절했습니다!! 또 다음날 조식은 클럽 라운지 조식을 이용했는데 사람이 많지 않고 메뉴가 알차서 맛있게 먹었습니다ㅎㅎ 요즘 좋은 사람들과 좋은 곳에서 즐거운 시간 보내기 쉽지 않은데그럴 때 롯데호텔 서울에서의 호캉스 정말 추천합니다!!
#
#
#  # 23 : 2019년 12월
# 이름 : yoonju cho
# 제목 : 결혼 25주년 기념으로 큰맘 먹고  성탄절 이브 롯데 호텔에 숙박을 하게 되었습니다
# 내용 : 호텔에 들어 서자 마자 성탄절이구나   요즘 찾아 보기 힘든 분위기 였는대 역쉬나 화려하고 캐럴송이 저절로 나오는 분위기에 객실이 너무 아늑하고 깨끗해서  30주년 35주년 꼭 다시 찾을것 같은  호텔입니다  호텔 체크인에서 부터 무엇 하나 흠잡을 것이 없는 성탄절 이였습니다
#
#
#  # 24 : 2019년 12월
# 이름 : 꼬라지
# 제목 : 즐거운 여행 재방문 100% 입니다.~
# 내용 : 연말을 맞이 하여 3대가  찾은 롯데 호텔은 저한테 감동을 선사했네요~  어린아이 부터 연세가 많으시  부모님까 모두 만족한 여행이였습니다. 연말이라서 많이  사람들로  불편을 예상했지만 제 예상을 깨고 직원분들의 친절 함에 즐거운 여행였습니다. 특히 어린아이 와  연세많은 신 부모님과 수영장 및 휘트니스 이용시 걱정을 많이했는데 직원분들이 먼저 다가오셔셔 이용방법도 설명해주시고 미소를 잃지 않는 서비스 정말 잊지 못할것 같네요~~ 룸 컨티션 ,직원분들 서비스 마인드 , 훌륭한 위치( 관광지.쇼핑센터), 보너스로 맛있는 조식까지 재 방문 100%입니다.~ 즐거운 여행 만들어 주셔서 감사합니다.^^
#
#
#  # 25 : 2019년 8월
# 이름 : 정인우
# 제목 : 추천합니다
# 내용 : 두말 필요없이 깔끔한 시설과 서비스로 만족합니다 조식도 맛있었고 근처에 관광지가 가까워 친구들과 즐겁게 여행할수 있었습니다
#
#
#  # 26 : 2019년 12월
# 이름 : CSM
# 제목 : 너무 좋아요~
# 내용 : 객실이용좋고 수영장.휘트니스시설도 무료이용할수있어 좋았고 직원들도 너무 친절해서 좋았어욤~~^.^ 애들데리고 가기 좋네요^.^
#
#
#  # 27 : 2019년 12월
# 이름 : Jenn
# 제목 : 좋은 곳에서 즐거운 시간 보냈습니다~!!
# 내용 : 요즘 바쁜 시간 속에서 항상 피곤하고 지친 상태였는데 친구들과 연말&크리스마스 기념으로 서울 도심에서 호캉스를 즐기기 위해 롯데호텔 서울을 선택했습니다!! 서울 한 가운데 위치하여 있어 접근성은 물론이고 바로 밑에 백화점, 영플라자 등 편의 시설도 많습니다. 그리고 백화점과 이어져 있어 찾아가기도 쉬워요!! 무엇보다 객실에 딱 들어갔을 때 깔끔하고 분위기가 너무 좋았습니다ㅎㅎ 특히 화장실이 정말 청결했어요!! 또 필요한 것이 있어 직원분께 부탁했더니 바로 가져다주시고 친절했습니다!! 또 다음날 조식은 클럽 라운지 조식을 이용했는데 사람이 많지 않고 메뉴가 알차서 맛있게 먹었습니다ㅎㅎ 요즘 좋은 사람들과 좋은 곳에서 즐거운 시간 보내기 쉽지 않은데그럴 때 롯데호텔 서울에서의 호캉스 정말 추천합니다!!
#
#
#  # 28 : 2019년 12월
# 이름 : yoonju cho
# 제목 : 결혼 25주년 기념으로 큰맘 먹고  성탄절 이브 롯데 호텔에 숙박을 하게 되었습니다
# 내용 : 호텔에 들어 서자 마자 성탄절이구나   요즘 찾아 보기 힘든 분위기 였는대 역쉬나 화려하고 캐럴송이 저절로 나오는 분위기에 객실이 너무 아늑하고 깨끗해서  30주년 35주년 꼭 다시 찾을것 같은  호텔입니다  호텔 체크인에서 부터 무엇 하나 흠잡을 것이 없는 성탄절 이였습니다
#
#
#  # 29 : 2019년 12월
# 이름 : 꼬라지
# 제목 : 즐거운 여행 재방문 100% 입니다.~
# 내용 : 연말을 맞이 하여 3대가  찾은 롯데 호텔은 저한테 감동을 선사했네요~  어린아이 부터 연세가 많으시  부모님까 모두 만족한 여행이였습니다. 연말이라서 많이  사람들로  불편을 예상했지만 제 예상을 깨고 직원분들의 친절 함에 즐거운 여행였습니다. 특히 어린아이 와  연세많은 신 부모님과 수영장 및 휘트니스 이용시 걱정을 많이했는데 직원분들이 먼저 다가오셔셔 이용방법도 설명해주시고 미소를 잃지 않는 서비스 정말 잊지 못할것 같네요~~ 룸 컨티션 ,직원분들 서비스 마인드 , 훌륭한 위치( 관광지.쇼핑센터), 보너스로 맛있는 조식까지 재 방문 100%입니다.~ 즐거운 여행 만들어 주셔서 감사합니다.^^
#
#
#  # 30 : 2019년 8월
# 이름 : 정인우
# 제목 : 추천합니다
# 내용 : 두말 필요없이 깔끔한 시설과 서비스로 만족합니다 조식도 맛있었고 근처에 관광지가 가까워 친구들과 즐겁게 여행할수 있었습니다
#
#
#  # 31 : 2019년 12월
# 이름 : CSM
# 제목 : 너무 좋아요~
# 내용 : 객실이용좋고 수영장.휘트니스시설도 무료이용할수있어 좋았고 직원들도 너무 친절해서 좋았어욤~~^.^ 애들데리고 가기 좋네요^.^
#
#
#  # 32 : 2019년 12월
# 이름 : Jenn
# 제목 : 좋은 곳에서 즐거운 시간 보냈습니다~!!
# 내용 : 요즘 바쁜 시간 속에서 항상 피곤하고 지친 상태였는데 친구들과 연말&크리스마스 기념으로 서울 도심에서 호캉스를 즐기기 위해 롯데호텔 서울을 선택했습니다!! 서울 한 가운데 위치하여 있어 접근성은 물론이고 바로 밑에 백화점, 영플라자 등 편의 시설도 많습니다. 그리고 백화점과 이어져 있어 찾아가기도 쉬워요!! 무엇보다 객실에 딱 들어갔을 때 깔끔하고 분위기가 너무 좋았습니다ㅎㅎ 특히 화장실이 정말 청결했어요!! 또 필요한 것이 있어 직원분께 부탁했더니 바로 가져다주시고 친절했습니다!! 또 다음날 조식은 클럽 라운지 조식을 이용했는데 사람이 많지 않고 메뉴가 알차서 맛있게 먹었습니다ㅎㅎ 요즘 좋은 사람들과 좋은 곳에서 즐거운 시간 보내기 쉽지 않은데그럴 때 롯데호텔 서울에서의 호캉스 정말 추천합니다!!
#
#
#  # 33 : 2019년 12월
# 이름 : yoonju cho
# 제목 : 결혼 25주년 기념으로 큰맘 먹고  성탄절 이브 롯데 호텔에 숙박을 하게 되었습니다
# 내용 : 호텔에 들어 서자 마자 성탄절이구나   요즘 찾아 보기 힘든 분위기 였는대 역쉬나 화려하고 캐럴송이 저절로 나오는 분위기에 객실이 너무 아늑하고 깨끗해서  30주년 35주년 꼭 다시 찾을것 같은  호텔입니다  호텔 체크인에서 부터 무엇 하나 흠잡을 것이 없는 성탄절 이였습니다
#
#
#  # 34 : 2019년 12월
# 이름 : 꼬라지
# 제목 : 즐거운 여행 재방문 100% 입니다.~
# 내용 : 연말을 맞이 하여 3대가  찾은 롯데 호텔은 저한테 감동을 선사했네요~  어린아이 부터 연세가 많으시  부모님까 모두 만족한 여행이였습니다. 연말이라서 많이  사람들로  불편을 예상했지만 제 예상을 깨고 직원분들의 친절 함에 즐거운 여행였습니다. 특히 어린아이 와  연세많은 신 부모님과 수영장 및 휘트니스 이용시 걱정을 많이했는데 직원분들이 먼저 다가오셔셔 이용방법도 설명해주시고 미소를 잃지 않는 서비스 정말 잊지 못할것 같네요~~ 룸 컨티션 ,직원분들 서비스 마인드 , 훌륭한 위치( 관광지.쇼핑센터), 보너스로 맛있는 조식까지 재 방문 100%입니다.~ 즐거운 여행 만들어 주셔서 감사합니다.^^
#
#
#  # 35 : 2019년 8월
# 이름 : 정인우
# 제목 : 추천합니다
# 내용 : 두말 필요없이 깔끔한 시설과 서비스로 만족합니다 조식도 맛있었고 근처에 관광지가 가까워 친구들과 즐겁게 여행할수 있었습니다
#
#
#  # 36 : 2019년 12월
# 이름 : CSM
# 제목 : 너무 좋아요~
# 내용 : 객실이용좋고 수영장.휘트니스시설도 무료이용할수있어 좋았고 직원들도 너무 친절해서 좋았어욤~~^.^ 애들데리고 가기 좋네요^.^
#
#
#  # 37 : 2019년 12월
# 이름 : Jenn
# 제목 : 좋은 곳에서 즐거운 시간 보냈습니다~!!
# 내용 : 요즘 바쁜 시간 속에서 항상 피곤하고 지친 상태였는데 친구들과 연말&크리스마스 기념으로 서울 도심에서 호캉스를 즐기기 위해 롯데호텔 서울을 선택했습니다!! 서울 한 가운데 위치하여 있어 접근성은 물론이고 바로 밑에 백화점, 영플라자 등 편의 시설도 많습니다. 그리고 백화점과 이어져 있어 찾아가기도 쉬워요!! 무엇보다 객실에 딱 들어갔을 때 깔끔하고 분위기가 너무 좋았습니다ㅎㅎ 특히 화장실이 정말 청결했어요!! 또 필요한 것이 있어 직원분께 부탁했더니 바로 가져다주시고 친절했습니다!! 또 다음날 조식은 클럽 라운지 조식을 이용했는데 사람이 많지 않고 메뉴가 알차서 맛있게 먹었습니다ㅎㅎ 요즘 좋은 사람들과 좋은 곳에서 즐거운 시간 보내기 쉽지 않은데그럴 때 롯데호텔 서울에서의 호캉스 정말 추천합니다!!
#
#
#  # 38 : 2019년 12월
# 이름 : yoonju cho
# 제목 : 결혼 25주년 기념으로 큰맘 먹고  성탄절 이브 롯데 호텔에 숙박을 하게 되었습니다
# 내용 : 호텔에 들어 서자 마자 성탄절이구나   요즘 찾아 보기 힘든 분위기 였는대 역쉬나 화려하고 캐럴송이 저절로 나오는 분위기에 객실이 너무 아늑하고 깨끗해서  30주년 35주년 꼭 다시 찾을것 같은  호텔입니다  호텔 체크인에서 부터 무엇 하나 흠잡을 것이 없는 성탄절 이였습니다
#
#
#  # 39 : 2019년 12월
# 이름 : 꼬라지
# 제목 : 즐거운 여행 재방문 100% 입니다.~
# 내용 : 연말을 맞이 하여 3대가  찾은 롯데 호텔은 저한테 감동을 선사했네요~  어린아이 부터 연세가 많으시  부모님까 모두 만족한 여행이였습니다. 연말이라서 많이  사람들로  불편을 예상했지만 제 예상을 깨고 직원분들의 친절 함에 즐거운 여행였습니다. 특히 어린아이 와  연세많은 신 부모님과 수영장 및 휘트니스 이용시 걱정을 많이했는데 직원분들이 먼저 다가오셔셔 이용방법도 설명해주시고 미소를 잃지 않는 서비스 정말 잊지 못할것 같네요~~ 룸 컨티션 ,직원분들 서비스 마인드 , 훌륭한 위치( 관광지.쇼핑센터), 보너스로 맛있는 조식까지 재 방문 100%입니다.~ 즐거운 여행 만들어 주셔서 감사합니다.^^
#
#
#  # 40 : 2019년 8월
# 이름 : 정인우
# 제목 : 추천합니다
# 내용 : 두말 필요없이 깔끔한 시설과 서비스로 만족합니다 조식도 맛있었고 근처에 관광지가 가까워 친구들과 즐겁게 여행할수 있었습니다
